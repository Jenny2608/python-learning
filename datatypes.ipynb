# %%
#Today we are learning python datatypes
age=10
print("age", type(age))
name="Sam"
print("name", type(name))
GPA="9.5"
print("GPA", type(GPA))
bool=True
print("bool", type(bool))
password=None
print("password", type(password))
set={1,2,3,4,5}
print("set", type(set))
tuple=(1,2,3,4,5)
print("tuple", type(tuple))
list=[1,2,3,4,5]
print("list", type(list))   
dict={"name":"Sam","age":10}
print("dict", type(dict))
# Out:
# age <class 'int'>
# name <class 'str'>
# GPA <class 'str'>
# bool <class 'bool'>
# password <class 'NoneType'>
# set <class 'set'>
# tuple <class 'tuple'>
# list <class 'list'>
# dict <class 'dict'>

# %%
#Numbers
